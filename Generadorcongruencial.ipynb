# %% [markdown]
# <a href="https://colab.research.google.com/github/KatiaItzelCortes/EDP/blob/main/Generadorcongruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tabulate
import tabulate

# %%
def generador (a, c, m, x0):
    x1 = (a * x0 + c) %m
    return x1

# %%
n = 70
a = 8
c = 2
m = 64
x0 = 1

muestra = []
datos = []
for i in range(n):
    nuevo = generador(a, c, m, x0)
    muestra.append([i, x0, nuevo/64])
    datos.append(x0/64)
    x0 = nuevo
encabezados = ["i", "x_i", "x_{i+1}"]
print(tabulate.tabulate(muestra, headers = encabezados, tablefmt = "plsql", numalign = "center"))
# Out:
#  i    x_i    x_{i+1}
# ---  -----  ---------
#  0     1     0.15625
#  1    10     0.28125
#  2    18     0.28125
#  3    18     0.28125
#  4    18     0.28125
#  5    18     0.28125
#  6    18     0.28125
#  7    18     0.28125
#  8    18     0.28125
#  9    18     0.28125
# 10    18     0.28125
# 11    18     0.28125
# 12    18     0.28125
# 13    18     0.28125
# 14    18     0.28125
# 15    18     0.28125
# 16    18     0.28125
# 17    18     0.28125
# 18    18     0.28125
# 19    18     0.28125
# 20    18     0.28125
# 21    18     0.28125
# 22    18     0.28125
# 23    18     0.28125
# 24    18     0.28125
# 25    18     0.28125
# 26    18     0.28125
# 27    18     0.28125
# 28    18     0.28125
# 29    18     0.28125
# 30    18     0.28125
# 31    18     0.28125
# 32    18     0.28125
# 33    18     0.28125
# 34    18     0.28125
# 35    18     0.28125
# 36    18     0.28125
# 37    18     0.28125
# 38    18     0.28125
# 39    18     0.28125
# 40    18     0.28125
# ...
