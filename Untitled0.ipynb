# %% [markdown]
# <a href="https://colab.research.google.com/github/KatiaItzelCortes/EDP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Grafica y=x^2

import matplotlib.pyplot as plt
import numpy as np

# Generate x values from -5 to 5
x = np.linspace(-5, 5, 10)

# Calculate y values (y = x^2)
y = x**2

# Create the plot
plt.plot(x, y)

# Add labels and title
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gráfica de y = x^2")

# Display the plot
plt.grid(True) # Add a grid for better readability
plt.show()
